# %% [markdown]
# <a href="https://colab.research.google.com/github/bryan2003Q/ArquitecturaComputadores/blob/main/trabajocorreo(BryanQuishpe).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install paho-mqtt
# Out:
# Collecting paho-mqtt
#   Downloading paho-mqtt-1.6.1.tar.gz (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.4/99.4 kB 3.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: paho-mqtt
#   Building wheel for paho-mqtt (setup.py) ... done
#   Created wheel for paho-mqtt: filename=paho_mqtt-1.6.1-py3-none-any.whl size=62118 sha256=af64034ce3af029caa1cd5184abace450b396320e6d9e411f6676c4e0b00a225
#   Stored in directory: /root/.cache/pip/wheels/8b/bb/0c/79444d1dee20324d442856979b5b519b48828b0bd3d05df84a
# Successfully built paho-mqtt
# Installing collected packages: paho-mqtt
# Successfully installed paho-mqtt-1.6.1

# %%
 pip install yagmail[all]
# Out:
# Collecting yagmail[all]
#   Downloading yagmail-0.15.293-py2.py3-none-any.whl (17 kB)
# Collecting premailer (from yagmail[all])
#   Downloading premailer-3.10.0-py2.py3-none-any.whl (19 kB)
# Collecting keyring (from yagmail[all])
#   Downloading keyring-24.2.0-py3-none-any.whl (37 kB)
# Collecting dkimpy (from yagmail[all])
#   Downloading dkimpy-1.1.4.tar.gz (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 7.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting dnspython>=1.16.0 (from dkimpy->yagmail[all])
#   Downloading dnspython-2.3.0-py3-none-any.whl (283 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 14.9 MB/s eta 0:00:00
# Collecting jaraco.classes (from keyring->yagmail[all])
#   Downloading jaraco.classes-3.3.0-py3-none-any.whl (5.9 kB)
# Collecting importlib-metadata>=4.11.4 (from keyring->yagmail[all])
#   Downloading importlib_metadata-6.8.0-py3-none-any.whl (22 kB)
# Collecting SecretStorage>=3.2 (from keyring->yagmail[all])
#   Downloading SecretStorage-3.3.3-py3-none-any.whl (15 kB)
# Collecting jeepney>=0.4.2 (from keyring->yagmail[all])
#   Downloading jeepney-0.8.0-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from premailer->yagmail[all]) (4.9.3)
# Collecting cssselect (from premailer->yagmail[all])
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Collecting cssutils (from premailer->yagmail[all])
#   Downloading cssutils-2.7.1-py3-none-any.whl (399 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 399.7/399.7 kB 36.6 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from premailer->yagmail[all]) (2.27.1)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from premailer->yagmail[all]) (5.3.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.11.4->keyring->yagmail[all]) (3.15.0)
# Collecting cryptography>=2.0 (from SecretStorage>=3.2->keyring->yagmail[all])
#   Downloading cryptography-41.0.2-cp37-abi3-manylinux_2_28_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 72.6 MB/s eta 0:00:00
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from jaraco.classes->keyring->yagmail[all]) (9.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->premailer->yagmail[all]) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->premailer->yagmail[all]) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->premailer->yagmail[all]) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->premailer->yagmail[all]) (3.4)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=2.0->SecretStorage>=3.2->keyring->yagmail[all]) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=2.0->SecretStorage>=3.2->keyring->yagmail[all]) (2.21)
# Building wheels for collected packages: dkimpy
#   Building wheel for dkimpy (setup.py) ... done
#   Created wheel for dkimpy: filename=dkimpy-1.1.4-py3-none-any.whl size=49977 sha256=7c0edaaf68f386def5938e99a8eecc430dd069d9f54e4fc615b359fa8ecaa9c8
#   Stored in directory: /root/.cache/pip/wheels/77/b3/64/c4c9fec40aaad1c4207da0c271727640bd36940e4d04835d3e
# Successfully built dkimpy
# Installing collected packages: jeepney, jaraco.classes, importlib-metadata, dnspython, cssutils, cssselect, premailer, dkimpy, cryptography, yagmail, SecretStorage, keyring
# Successfully installed SecretStorage-3.3.3 cryptography-41.0.2 cssselect-1.2.0 cssutils-2.7.1 dkimpy-1.1.4 dnspython-2.3.0 importlib-metadata-6.8.0 jaraco.classes-3.3.0 jeepney-0.8.0 keyring-24.2.0 premailer-3.10.0 yagmail-0.15.293

# %%
from paho.mqtt import client as mqtt_client
import random
import json
import time
import yagmail

# Hive
BROKER = 'broker.hivemq.com'
PORT = 1883
TOPIC_DATA = "mensaje"
TOPIC_ALERT = "mensaje"
CLIENT_ID = "python-mqtt-tcp-pub-sub-{id}".format(id=random.randint(0, 1000))
FLAG_CONNECTED = 0

def on_connect(client, userdata, flags, rc):
    global FLAG_CONNECTED
    if rc == 0:
        FLAG_CONNECTED = 1
        print("Connected to MQTT Broker!")
        client.subscribe(TOPIC_DATA)
        client.subscribe(TOPIC_ALERT)
    else:
        print("Failed to connect, return code {rc}".format(rc=rc))


def on_message(client, userdata, msg):
    try:
        print("Received `{payload}` from `{topic}` topic".format(payload=msg.payload.decode(), topic=msg.topic))
        publish(client, TOPIC_ALERT, )

    except Exception as e:
        print(e)

def connect_mqtt():
    client = mqtt_client.Client(CLIENT_ID)
    client.on_connect = on_connect
    client.on_message = on_message
    client.connect(BROKER, PORT)
    return client

def publish(client, topic, message):
    msg = json.dumps(message)
    result = client.publish(topic, msg)

client = connect_mqtt()

#correo electronico
email = 'quishpebryan10mob@gmail.com'
contraseña = 'oihqcvwoxpaevsbz'






def run():
    counter = 1

    while True:
        client.loop_start()
        time.sleep(1)

        if FLAG_CONNECTED:
            if counter % 10 == 0:
                publish(client, TOPIC_ALERT, counter)
                publish(client, TOPIC_ALERT, "Multiplo de 10: {counter}".format(counter=counter))
                yag = yagmail.SMTP(user=email, password=contraseña)
                destinatarios = ['quishpebryan1234@gmail.com']
                asunto = 'multiplo de 10'
                mensaje = 'El número {counter} es múltiplo de 10'.format(counter=counter)
                yag.send(destinatarios, asunto, mensaje)
            else:
                publish(client, TOPIC_ALERT, counter)
            counter += 1
        else:
            client.loop_stop()

if __name__ == '__main__':
    run()
# Out:
# Connected to MQTT Broker!
# Received `1` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `1` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `1` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `1` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `1` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `1` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `1` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `2` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `2` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `2` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `2` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `2` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `2` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `2` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `3` from `mensaje` topicReceived `3` from `mensaje` topicReceived `3` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `3` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# publish() missing 1 required positional argument: 'message'
# Received `3` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
#
# Received `3` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
#
# publish() missing 1 required positional argument: 'message'
# Received `3` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `4` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `4` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `4` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `4` from `mensaje` topicReceived `4` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `4` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `4` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
#
# publish() missing 1 required positional argument: 'message'
# Received `5` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `5` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `5` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `5` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `5` from `mensaje` topicReceived `5` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
#
# publish() missing 1 required positional argument: 'message'
# Received `5` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `6` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `6` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `6` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `6` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `6` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `6` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `6` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `7` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `7` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `7` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `7` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `7` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `7` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `7` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `8` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `8` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `8` from `mensaje` topicReceived `8` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `8` from `mensaje` topic
#
# publish() missing 1 required positional argument: 'message'Received `8` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
#
# publish() missing 1 required positional argument: 'message'
# Received `8` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `9` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `9` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `9` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `9` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `9` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `9` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `9` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `10` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `10` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `10` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `10` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `10` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `10` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `10` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `"Multiplo de 10: 10"` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `"Multiplo de 10: 10"` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `"Multiplo de 10: 10"` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `"Multiplo de 10: 10"` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `"Multiplo de 10: 10"` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `"Multiplo de 10: 10"` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `"Multiplo de 10: 10"` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `11` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `11` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `11` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `11` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `11` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `11` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `11` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `12` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `12` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `12` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `12` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `12` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `12` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `12` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `13` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `13` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `13` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `13` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `13` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `13` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `13` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `14` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `14` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'Received `14` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
#
# Received `14` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `14` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `14` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `14` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `15` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `15` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `15` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `15` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `15` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `15` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `15` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `16` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `16` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `16` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `16` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `16` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `16` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `16` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `17` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `17` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'Received `17` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `17` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
#
# Received `17` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `17` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `17` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `18` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `18` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `18` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `18` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `18` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `18` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `18` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `19` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `19` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `19` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `19` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `19` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `19` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `19` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `20` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `20` from `mensaje` topicReceived `20` from `mensaje` topic
#
# publish() missing 1 required positional argument: 'message'
# publish() missing 1 required positional argument: 'message'
# Received `20` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `20` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `20` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `20` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `"Multiplo de 10: 20"` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `"Multiplo de 10: 20"` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `"Multiplo de 10: 20"` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `"Multiplo de 10: 20"` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `"Multiplo de 10: 20"` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `"Multiplo de 10: 20"` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `"Multiplo de 10: 20"` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `21` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `21` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `21` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `21` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `21` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `21` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `21` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `22` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `22` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `22` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `22` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `22` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `22` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `22` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `23` from `mensaje` topicReceived `23` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# publish() missing 1 required positional argument: 'message'
# Received `23` from `mensaje` topicReceived `23` from `mensaje` topic
#
# Received `23` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'publish() missing 1 required positional argument: 'message'
#
# publish() missing 1 required positional argument: 'message'
# Received `23` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
#
# Received `23` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `24` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `24` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `24` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `24` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `24` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `24` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `24` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `25` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `25` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `25` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `25` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `25` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `25` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `25` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `26` from `mensaje` topic
# Received `26` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# publish() missing 1 required positional argument: 'message'
# Received `26` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `26` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `26` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `26` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `26` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `27` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `27` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `27` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `27` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `27` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `27` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `27` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `28` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `28` from `mensaje` topicReceived `28` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
#
# publish() missing 1 required positional argument: 'message'
# Received `28` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `28` from `mensaje` topicReceived `28` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
#
# publish() missing 1 required positional argument: 'message'
# Received `28` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `29` from `mensaje` topicReceived `29` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `29` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
#
# publish() missing 1 required positional argument: 'message'
# Received `29` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `29` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `29` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `29` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `30` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `30` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `30` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `30` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `30` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `30` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `30` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `"Multiplo de 10: 30"` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `"Multiplo de 10: 30"` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `"Multiplo de 10: 30"` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `"Multiplo de 10: 30"` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `"Multiplo de 10: 30"` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `"Multiplo de 10: 30"` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `"Multiplo de 10: 30"` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `31` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `31` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `31` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `31` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `31` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `31` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `31` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `32` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `32` from `mensaje` topic
# Received `32` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `32` from `mensaje` topic
# Received `32` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# publish() missing 1 required positional argument: 'message'
# publish() missing 1 required positional argument: 'message'
# Received `32` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `32` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `33` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `33` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `33` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `33` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `33` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `33` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `33` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `34` from `mensaje` topicReceived `34` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `34` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
#
# publish() missing 1 required positional argument: 'message'
# Received `34` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `34` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `34` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `34` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `35` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `35` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `35` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `35` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `35` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `35` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `35` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `36` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `36` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `36` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `36` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `36` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `36` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `36` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `37` from `mensaje` topicReceived `37` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `37` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `37` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
#
# publish() missing 1 required positional argument: 'message'
# Received `37` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `37` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `37` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `38` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `38` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `38` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `38` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `38` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `38` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `38` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `39` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `39` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `39` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `39` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `39` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `39` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `39` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `40` from `mensaje` topicReceived `40` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
#
# publish() missing 1 required positional argument: 'message'
# Received `40` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `40` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'Received `40` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `40` from `mensaje` topic
# Received `40` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
#
# publish() missing 1 required positional argument: 'message'
# Received `"Multiplo de 10: 40"` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `"Multiplo de 10: 40"` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `"Multiplo de 10: 40"` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `"Multiplo de 10: 40"` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `"Multiplo de 10: 40"` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `"Multiplo de 10: 40"` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `"Multiplo de 10: 40"` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `41` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `41` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `41` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `41` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `41` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `41` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `41` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `42` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `42` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `42` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `42` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `42` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `42` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `42` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `43` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `43` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `43` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `43` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `43` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `43` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `43` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `44` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `44` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `44` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `44` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `44` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `44` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `44` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `45` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `45` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `45` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `45` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `45` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `45` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `45` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `46` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `46` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `46` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `46` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `46` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `46` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `46` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `47` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `47` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `47` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `47` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# Received `47` from `mensaje` topic
# Received `47` from `mensaje` topic
# publish() missing 1 required positional argument: 'message'
# publish() missing 1 required positional argument: 'message'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-16723c6028e5> in <cell line: 78>()
#      77
#      78 if __name__ == '__main__':
# ---> 79     run()
#
# <ipython-input-11-16723c6028e5> in run()
#      59     while True:
#      60         client.loop_start()
# ---> 61         time.sleep(1)
#      62
#      63         if FLAG_CONNECTED:
#
# KeyboardInterrupt:
